# %%
#print row ที่มี Duration ต่ำกว่า 150
import pandas as pd
import numpy as np

# %%
a = pd.read_csv("data.csv")
for x in a.index:
  if a.loc[x, "Duration"] < 150:
     print(a.loc[x])
# Out:
# Duration     60.0
# Pulse       110.0
# Maxpulse    130.0
# Calories    409.1
# Name: 0, dtype: float64
# Duration     60.0
# Pulse       117.0
# Maxpulse    145.0
# Calories    479.0
# Name: 1, dtype: float64
# Duration     60.0
# Pulse       103.0
# Maxpulse    135.0
# Calories    340.0
# Name: 2, dtype: float64
# Duration     45.0
# Pulse       109.0
# Maxpulse    175.0
# Calories    282.4
# Name: 3, dtype: float64
# Duration     45.0
# Pulse       117.0
# Maxpulse    148.0
# Calories    406.0
# Name: 4, dtype: float64
# Duration     60.0
# Pulse       102.0
# Maxpulse    127.0
# Calories    300.0
# Name: 5, dtype: float64
# Duration     60.0
# Pulse       110.0
# Maxpulse    136.0
# Calories    374.0
# Name: 6, dtype: float64
# Duration     45.0
# Pulse       104.0
# Maxpulse    134.0
# Calories    253.3
# Name: 7, dtype: float64
# Duration     30.0
# Pulse       109.0
# Maxpulse    133.0
# Calories    195.1
# Name: 8, dtype: float64
# Duration     60.0
# Pulse        98.0
# ...
